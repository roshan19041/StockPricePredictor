# %% [markdown]
# ### Prediction of Stock Prices using a Deep-LSTM Network<br>
#
# The trained LSTM network (refer code) is used to make predictions on a held-out, validation dataset and the results are plotted below. The model was trained using historical time-series data for Pfizer(traded on the NYSE as 'PFE').
#
# About 20% of the (most recent) data points was included in the validation dataset and the data corresponding to the first 80% chunk of the time-series was used as the training data.

# %%
from IPython.display import Image

# %%
Image(filename='Predictions.png')
